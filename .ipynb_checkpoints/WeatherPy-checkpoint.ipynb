# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude

from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
#lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %%
cities_df = pd.DataFrame(cities,columns={"City"})
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="


cities_df["Lat"] = ""
cities_df["Lng"] = ""
cities_df["Max Temp"] = ""
cities_df["Cloudiness"] = ""
cities_df["Country"] = ""
cities_df["Date"] = ""
cities_df["Humidity"] = ""
cities_df["Wind Speed"] = ""

s = 0
count = 1

for index,row in cities_df.iterrows():
    city = row["City"]
    if index%50==0:
        s+=1
        count=1
    
    response = requests.get(query_url + city).json()
    try:
        print(f"Processing Record {count} of Set {s} | {city}")
        cities_df.loc[index,"Lat"] = response['coord']['lat']
        cities_df.loc[index,"Lng"] =response["coord"]["lon"]
        cities_df.loc[index,"Max Temp"] = response['main']['temp_max']
        cities_df.loc[index,"Cloudiness"] =response["clouds"]["all"]
        cities_df.loc[index,"Country"] =response["sys"]["country"]
        cities_df.loc[index,"Date"] = response["dt"]
        cities_df.loc[index,"Humidity"] = response["main"]["humidity"]
        cities_df.loc[index,"Wind Speed"] = response["wind"]["speed"]
        count+=1
    except:
        print("City not found. Skipping...")
# Out:
# Processing Record 1 of Set 1 | san patricio
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | bonthe
# Processing Record 5 of Set 1 | upernavik
# Processing Record 6 of Set 1 | elko
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | iqaluit
# Processing Record 9 of Set 1 | buin
# Processing Record 10 of Set 1 | fairbanks
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | west bay
# Processing Record 13 of Set 1 | labelle
# Processing Record 14 of Set 1 | haines junction
# Processing Record 15 of Set 1 | komsomolskiy
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | severodvinsk
# Processing Record 18 of Set 1 | ypacarai
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 1 | leningradskiy
# Processing Record 21 of Set 1 | panzhihua
# Processing Record 22 of Set 1 | hay river
# Processing Record 23 of Set 1 | nanortalik
# Processing Record 24 of Set 1 | provideniya
# Processing Record 25 of Set 1 | namibe
# Processing Record 26 of Set 1 | saint-francois
# Processing Record 27 of Set 1 | qasigiannguit
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | teya
# Processing Record 30 of Set 1 | mampong
# Processing Record 31 of Set 1 | dunmore town
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record
# Processing Record 17 of Set 4 | port alfred
# Processing Record 18 of Set 4 | ballina
# Processing Record 19 of Set 4 | broken hill
# Processing Record 20 of Set 4 | capinzal
# Processing Record 21 of Set 4 | edmundston
# Processing Record 22 of Set 4 | college
# Processing Record 23 of Set 4 | tignere
# Processing Record 24 of Set 4 | gat
# Processing Record 25 of Set 4 | meulaboh
# Processing Record 26 of Set 4 | broome
# Processing Record 27 of Set 4 | port-gentil
# Processing Record 28 of Set 4 | ust-nera
# Processing Record 29 of Set 4 | troitsko-pechorsk
# Processing Record 30 of Set 4 | mar del plata
# Processing Record 31 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 4 | terralba
# Processing Record 32 of Set 4 | launceston
# Processing Record 33 of Set 4 | tuatapere
# Processing Record 34 of Set 4 | kushima
# Processing Record 35 of Set 4 | salalah
# Processing Record 36 of Set 4 | severo-kurilsk
# Processing Record 37 of Set 4 | chuy
# Processing Record 38 of Set 4 | skjervoy
# Processing Record 39 of Set 4 | vila franca do campo
# Processing Record 40 of Set 4 | hobart
# Processing Record 41 of Set 4 | ponta do sol
# Processing Record 42 of Set 4 | dikson
# Processing Record 43 of Set 4 | djenne
# Processing Record 44 of Set 4 | yulara
# Processing Record 45 of Set 4 | akdepe
# Processing Record 46 of Set 4 | kodiak
# Processing Record 47 of Set 4 | comodoro rivadavia
# Processing Record 1 of Set 5 | belmonte
# Processing Record 2 of Set 5 | barrow
# Processing Record 3 of Set 5 | tezu
# Processing Record 4 of Set 5 | talnakh
# Processing Record 5 of Set 5 | petawawa
# Processing Record 6 of Set 5 | waipawa
# Processing Record 7 of Set 5 | miandrivazo
# Processing Record 8 of Set 5 | beloha
# Processing Record 9 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 5 | kyaikto
# Processing Record 10 of Set 5 | narsaq
# Processing Record 11 of Set 5 | campbell river
# Processing Record 12 of Set 5 | kruisfontein
# Processing Record 13 of Set 5 | sihora
# Processing Record 14 of Set 5 | souillac
# Processing Record 15 of Set 5 | culaman
# Processing Record 16 of Set 5 | virginia beach
# Processing Record 17 of Set 5 | monterey
# Processing Record 18 of Set 5 | duz
# City not found. Skipping...
# Processing Record 18 of Set 5 | sunrise manor
# Processing Record 19 of Set 5 | anloga
# Processing Record 20 of Set 5 | leh
# Processing Record 21 of Set 5 | fare
# Processing Record 22 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 5 | vallenar
# Processing Record 23 of Set 5 | auki
# Processing Record 24 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 24 of Set 5 | zhigansk
# Processing Record 25 of Set 5 | danville
# Processing Record 26 of Set 5 | tuy hoa
# Processing Record 27 of Set 5 | rawah
# City not found. Skipping...
# Processing Record 27 of Set 5 | ginda
# Processing Record 28 of Set 5 | shirokiy
# Processing Record 29 of Set 5 | sept-iles
# Processing Record 30 of Set 5 | maniitsoq
# Processing Record 31 of Set 5 | svetlogorsk
# Processing Record 32 of Set 5 | acapulco
# Processing Record 33 of Set 5 | taupo
# Processing Record 34 of Set 5 | boysun
# Processing Record 35 of Set 5 | sal rei
# Processing Record 36 of Set 5 | morwell
# Processing Record 37 of Set 5 | yellowknife
# Processing Record 38 of Set 5 | saldanha
# Processing Record 39 of Set 5 | victoria
# Processing Record 40 of Set 5 | hofn
# Processing Record 41 of Set 5 | kamaishi
# Processing Record 42 of Set 5 | pisco
# Processing Record 43 of Set 5 | vardo
# Processing Record 44 of Set 5 | sidi qasim
# City not found. Skipping...
# Processing Record 44 of Set 5 | abu kamal
# Processing Record 1 of Set 6 | houma
# Processing Record 2 of Set 6 | washington
# Processing Record 3 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 6 | fort nelson
# Processing Record 4 of Set 6 | vysokogornyy
# Processing Record 5 of Set 6 | khani
# Processing Record 6 of Set 6 | makat
# Processing Record 7 of Set 6 | nazarovo
# Processing Record 8 of Set 6 | yumen
# Processing Record 9 of Set 6 | lae
# Processing Record 10 of Set 6 | nanga eboko
# Processing Record 11 of Set 6 | camacha
# Processing Record 12 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 6 | bambous virieux
# Processing Record 13 of Set 6 | port lincoln
# Processing Record 14 of Set 6 | sidi ali
# Processing Record 15 of Set 6 | flinders
# Processing Record 16 of Set 6 | puerto baquerizo moreno
# Processing Record 17 of Set 6 | bilokurakyne
# Processing Record 18 of Set 6 | longyearbyen
# Processing Record 19 of Set 6 | olga
# Processing Record 20 of Set 6 | soissons
# Processing Record 21 of Set 6 | marsa matruh
# Processing Record 22 of Set 6 | viedma
# Processing Record 23 of Set 6 | mendahara
# City not found. Skipping...
# Processing Record 23 of Set 6 | sao filipe
# Processing Record 24 of Set 6 | port arthur
# Processing Record 25 of Set 6 | mahebourg
# Processing Record 26 of Set 6 | yar-sale
# Processing Record 27 of Set 6 | fortuna foothills
# Processing Record 28 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 6 | cap malheureux
# Processing Record 29 of Set 6 | santo antonio do amparo
# Processing Record 30 of Set 6 | olinda
# Processing Record 31 of Set 6 | pereira barreto
# Processing Record 32 of Set 6 | makakilo city
# Processing Record 33 of Set 6 | vostok
# Processing Record 34 of Set 6 | krasnoturansk
# Processing Record 35 of Set 6 | padang
# Processing Record 36 of Set 6 | sovetskaya gavan
# Processing Record 37 of Set 6 | puerto el triunfo
# Processing Record 38 of Set 6 | hammerfest
# Processing Record 39 of Set 6 | beira
# Processing Record 40 of Set 6 | lishui
# Processing Record 41 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 6 | dunedin
# Processing Record 42 of Set 6 | lebu
# Processing Record 43 of Set 6 | buraydah
# Processing Record 44 of Set 6 | elliot
# Processing Record 45 of Set 6 | tura
# Processing Record 1 of Set 7 | faanui
# Processing Record 2 of Set 7 | costa rica
# Processing Record 3 of Set 7 | nuuk
# Processing Record 4 of Set 7 | sisimiut
# Processing Record 5 of Set 7 | mitu
# Processing Record 34 of Set 9 | sabha
# Processing Record 35 of Set 9 | anadyr
# Processing Record 36 of Set 9 | lerwick
# Processing Record 37 of Set 9 | shimoda
# Processing Record 38 of Set 9 | ramona
# Processing Record 39 of Set 9 | coquimbo
# Processing Record 40 of Set 9 | sungairaya
# Processing Record 41 of Set 9 | robe
# Processing Record 42 of Set 9 | turtkul
# City not found. Skipping...
# Processing Record 42 of Set 9 | sainte-martine
# Processing Record 1 of Set 10 | clyde river
# Processing Record 2 of Set 10 | ban tak
# Processing Record 3 of Set 10 | santa marta
# Processing Record 4 of Set 10 | yabelo
# Processing Record 5 of Set 10 | whitehorse
# Processing Record 6 of Set 10 | mount isa
# Processing Record 7 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 10 | sakakah
# City not found. Skipping...
# Processing Record 7 of Set 10 | marsh harbour
# Processing Record 8 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 10 | alofi
# Processing Record 9 of Set 10 | kobryn
# Processing Record 10 of Set 10 | oranjemund
# Processing Record 11 of Set 10 | mudanya
# Processing Record 12 of Set 10 | baltay
# Processing Record 13 of Set 10 | tungor
# Processing Record 14 of Set 10 | tshane
# Processing Record 15 of Set 10 | obluche
# City not found. Skipping...
# Processing Record 15 of Set 10 | staraya toropa
# Processing Record 16 of Set 10 | altamont
# Processing Record 17 of Set 10 | shawville
# Processing Record 18 of Set 10 | chapais
# Processing Record 19 of Set 10 | francavilla al mare
# Processing Record 20 of Set 10 | lyaskelya
# Processing Record 21 of Set 10 | altar
# Processing Record 22 of Set 10 | zeven
# Processing Record 23 of Set 10 | roma
# Processing Record 24 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 24 of Set 10 | villablino
# Processing Record 25 of Set 10 | porto santo
# City not found. Skipping...
# Processing Record 25 of Set 10 | aitape
# Processing Record 26 of Set 10 | cidreira
# Processing Record 27 of Set 10 | baijiantan
# Processing Record 28 of Set 10 | burnie
# Processing Record 29 of Set 10 | gibara
# Processing Record 30 of Set 10 | santander jimenez
# Processing Record 31 of Set 10 | troy
# Processing Record 32 of Set 10 | vangaindrano
# Processing Record 33 of Set 10 | batagay
# Processing Record 34 of Set 10 | stilfontein
# Processing Record 35 of Set 10 | vaitape
# Processing Record 36 of Set 10 | ploemeur
# Processing Record 37 of Set 10 | thanh hoa
# Processing Record 38 of Set 10 | noumea
# Processing Record 39 of Set 10 | erdenet
# Processing Record 40 of Set 10 | cockburn town
# Processing Record 41 of Set 10 | santa rosalia
# Processing Record 42 of Set 10 | beringovskiy
# Processing Record 43 of Set 10 | sangar
# Processing Record 44 of Set 10 | amahai
# Processing Record 1 of Set 11 | sao jose da coroa grande
# Processing Record 2 of Set 11 | bachaquero
# Processing Record 3 of Set 11 | kontagora
# Processing Record 4 of Set 11 | visby
# Processing Record 5 of Set 11 | beidao
# Processing Record 6 of Set 11 | pitimbu
# Processing Record 7 of Set 11 | zabaykalsk
# Processing Record 8 of Set 11 | kurchatov
# Processing Record 9 of Set 11 | dubrovnik
# Processing Record 10 of Set 11 | hovd
# Processing Record 11 of Set 11 | mayo
# Processing Record 12 of Set 11 | shieli
# Processing Record 13 of Set 11 | norman wells
# Processing Record 14 of Set 11 | farafangana
# Processing Record 15 of Set 11 | veraval
# Processing Record 16 of Set 11 | zeya
# Processing Record 17 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 17 of Set 11 | bolshaya dzhalga
# Processing Record 18 of Set 11 | itarema
# Processing Record 19 of Set 11 | khorixas
# Processing Record 20 of Set 11 | jinan
# Processing Record 21 of Set 11 | manado
# Processing Record 22 of Set 11 | podor
# Processing Record 23 of Set 11 | severo-yeniseyskiy
# Processing Record 24 of Set 11 | touros
# Processing Record 25 of Set 11 | payo
# Processing Record 26 of Set 11 | saint-omer
# Processing Record 27 of Set 11 | hirara
# Processing Record 28 of Set 11 | hun
# Processing Record 29 of Set 11 | orodara
# Processing Record 30 of Set 11 | manzanillo
# Processing Record 31 of Set 11 | mandalgovi
# Processing Record 32 of Set 11 | mugur-aksy
# Processing Record 33 of Set 11 | tigil
# Processing Record 34 of Set 11 | wanlaweyn
# Processing Record 35 of Set 11 | olafsvik
# City not found. Skipping...
# Processing Record 35 of Set 11 | tierralta
# Processing Record 36 of Set 11 | harlingen
# Processing Record 37 of Set 11 | pires do rio
# Processing Record 38 of Set 11 | okakarara
# Processing Record 39 of Set 11 | novikovo
# Processing Record 40 of Set 11 | honningsvag
# Processing Record 41 of Set 11 | dawei
# Processing Record 42 of Set 11 | staryy nadym
# Processing Record 43 of Set 11 | bida
# Processing Record 44 of Set 11 | roebourne
# Processing Record 45 of Set 11 | frederikshavn
# Processing Record 46 of Set 11 | havoysund
# Processing Record 47 of Set 11 | linhares
# Processing Record 48 of Set 11 | vestmanna
# Processing Record 1 of Set 12 | miri
# Processing Record 2 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 2 of Set 12 | manching
# Processing Record 3 of Set 12 | naliya
# Processing Record 4 of Set 12 | udachnyy
# Processing Record 5 of Set 12 | suarez
# Processing Record 6 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 6 of Set 12 | lufilufi
# Processing Record 7 of Set 12 | tomatlan
# Processing Record 8 of Set 12 | mogadishu
# Processing Record 9 of Set 12 | dingle
# Processing Record 10 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 10 of Set 12 | labis
# Processing Record 11 of Set 12 | niquelandia
# Processing Record 12 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 12 of Set 12 | khash
# Processing Record 13 of Set 12 | batticaloa
# Processing Record 14 of Set 12 | nkoyaphiri
# Processing Record 15 of Set 12 | muroto
# Processing Record 16 of Set 12 | hearst
# Processing Record 17 of Set 12 | necochea
# Processing Record 18 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 12 | kikwit
# Processing Record 19 of Set 12 | manta
# Processing Record 20 of Set 12 | rivera
# Processing Record 21 of Set 12 | egvekinot
# Processing Record 22 of Set 12 | margate
# Processing Record 23 of Set 12 | rangapara
# Processing Record 24 of Set 12 | tripoli
# Processing Record 25 of Set 12 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 12 | korhogo
# Processing Record 26 of Set 12 | mezen
# Processing Record 27 of Set 12 | envira
# City not found. Skipping...
# Processing Record 27 of Set 12 | shingu
# Processing Record 28 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 28 of Set 12 | nantucket
# Processing Record 29 of Set 12 | tiquicheo
# Processing Record 30 of Set 12 | garden city
# Processing Record 31 of Set 12 | kizema
# Processing Record 32 of Set 12 | bilibino
# Processing Record 33 of Set 12 | khandbari
# Processing Record 34 of Set 12 | imeni poliny osipenko
# Processing Record 35 of Set 12 | faya

# %%
cities_df = cities_df[cities_df["Humidity"]!=""].reset_index()
cities_df.head()
# Out:
#    index          City    Lat     Lng Max Temp Cloudiness Country        Date  \
# 0      0  san patricio -26.98  -56.83    74.62          0      PY  1542663882
# 1      1     busselton -33.64  115.35    52.48         32      AU  1542663882
# 2      2       rikitea -23.12 -134.97    76.78         80      PF  1542663882
# 3      3        bonthe   7.53   -12.5    83.35         44      SL  1542663882
# 4      4     upernavik  72.79  -56.15    21.74          0      GL  1542663882
#
#   Humidity Wind Speed
# 0       72       4.36
# 1      100       9.62
# 2       96      15.66
# 3       68       2.01
# 4      100      18.79

# %%
cities_df.count()
# Out:
# index         537
# City          537
# Lat           537
# Lng           537
# Max Temp      537
# Cloudiness    537
# Country       537
# Date          537
# Humidity      537
# Wind Speed    537
# dtype: int64

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
fig, ax = plt.subplots()
ax.plot(cities_df["Lat"],cities_df["Max Temp"], label = "Max Temperature", color='steelblue', marker='o', mec = "k",
        linewidth=0, markersize=6)
ax.set_xlabel("Latitude")
ax.set_ylabel("Max Temperature (F)")
ax.set_title("City Latitude vs Max Temperature (11/19/2018)")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()
ax.plot(cities_df["Lat"],cities_df["Humidity"], label = "Humidity", color='steelblue', marker='o', mec = "k",
        linewidth=0, markersize=6)
ax.set_xlabel("Latitude")
ax.set_ylabel("Humidity (%)")
ax.set_title("City Latitude vs Humidity (11/19/2018)")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()
ax.plot(cities_df["Lat"],cities_df["Cloudiness"], label = "Humidity", color='steelblue', marker='o', mec = "k",
        linewidth=0, markersize=6)
ax.set_xlabel("Latitude")
ax.set_ylabel("Cloudiness (%)")
ax.set_title("City Latitude vs Cloudiness (11/19/2018)")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots()
ax.plot(cities_df["Lat"],cities_df["Wind Speed"], label = "Humidity", color='steelblue', marker='o', mec = "k",
        linewidth=0, markersize=6)
ax.set_xlabel("Latitude")
ax.set_ylabel("Wind Speed (mph)")
ax.set_title("City Latitude vs. Wind Speed (11/19/2018)")
plt.grid()
plt.show()
